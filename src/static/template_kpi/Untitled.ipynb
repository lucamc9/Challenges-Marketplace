# %%
import pandas as pd

# %%
excel = pd.ExcelFile('example-kpi.xlsx')

# %%
db_qs = excel.parse(excel.sheet_names[3])

# %%
db_qs
# Out:
#                                                                                                             CURRENT MONTH  \
# Income Statement Information NaN                                                                                      NaN
# NaN                          NaN                                                                                      NaN
#                              $  Sales by top customers                                                                NaN
#                              NaN                                                                               Customer A
#                              NaN                                                                               Customer B
#                              NaN                                                                               Customer C
#                              NaN                                                                               Customer D
# ...
